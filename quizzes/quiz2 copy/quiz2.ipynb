# %% [markdown]
# # <span style="color:darkblue"> QTM 151 - Quiz 2 </span>

# %% [markdown]
# ## Try to submit as an HTML file

# %% [markdown]
# <font size="5">
#
# Print your Emory code below

# %%
# Write your answer here
print("My ID number is 2521588")
# Out:
# My ID number is 2521588

# %% [markdown]
# <font size = "5" >
# This quiz is open book
#
# - You can use the lecture notes and Google
# - You will get partial credit for attempting the questions
# - To get full credit, the code should run as intended
# - You should <span style="color:red"> NOT </span> communicate with other students
#
# Print the following message: <br>
#
# "I will abide by Emory's code of conduct"
#
# **By printing the message, you acknowledge that you will abide by Emory's code of conduct.**

# %%
# Write your answer here:
print("I will abide by Emory's code of conduct")
# Out:
# I will abide by Emory's code of conduct

# %% [markdown]
# <font size = "5">
#
# Import the libraries "numpy", "matplotlib.pyplot", and "pandas"

# %%
# Write your answer here

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# <font size = "5">
#
# Import the dataset "data_quiz/fifa23_players_basic.csv"
#
# - It's a dataset on professional soccer players
# - Rows correspond to players (18,539)
# - Columns contain attributes of players (32)
# - Try to view the dataset before starting

# %%
# Write your own code
fifa23 = pd.read_csv("data_quiz/fifa23_players_basic.csv")

display(fifa23)
# Out:
#              Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0            L. Messi        Lionel Messi       91         91        54000000
# 1          K. Benzema       Karim Benzema       91         91        64000000
# 2      R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3        K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4           K. Mbappé       Kylian Mbappé       91         95       190500000
# ...               ...                 ...      ...        ...             ...
# 18534      D. Collins      Darren Collins       47         56          110000
# 18535    Yang Dejiang        Dejiang Yang       47         57           90000
# 18536       L. Mullan         Liam Mullan       47         67          130000
# 18537    D. McCallion    Daithí McCallion       47         61          100000
# 18538        N. Rabha         Nabin Rabha       47         50           60000
#
#       Positions Played Best Position          Nationality  \
# 0                   RW           CAM            Argentina
# 1                CF,ST            CF               France
# 2                   ST            ST               Poland
# 3               CM,CAM            CM              Belgium
# 4                ST,LW            ST               France
# ...                ...           ...                  ...
# 18534            ST,RM           CAM  Republic of Ireland
# 18535              CDM           CDM             China PR
# 18536               CM            RM     Northern Ireland
# 18537               CB            CB  Republic of Ireland
# 18538               LB            LB                India
#
#                                              Image Link  Age  ...  \
# 0      https://cdn.sofifa.net/players/158/023/23_60.png   35  ...
# 1      https://cdn.sofifa.net/players/165/153/23_60.png   34  ...
# 2      https://cdn.sofifa.net/players/188/545/23_60.png   33  ...
# 3      https://cdn.sofifa.net/players/192/985/23_60.png   31  ...
# 4      https://cdn.sofifa.net/players/231/747/23_60.png   23  ...
# ...                                                 ...  ...  ...
# 18534  https://cdn.sofifa.net/players/243/725/23_60.png   21  ...
# 18535  https://cdn.sofifa.net/players/261/933/23_60.png   17  ...
# 18536  https://cdn.sofifa.net/players/267/823/23_60.png   18  ...
# 18537  https://cdn.sofifa.net/players/267/824/23_60.png   17  ...
# 18538  https://cdn.sofifa.net/players/261/424/23_60.png   25  ...
#
#        Preferred Foot  Weak Foot Rating  Skill Moves  \
# 0                Left                 4            4
# 1               Right                 4            4
# 2               Right                 4            4
# 3               Right                 5            4
# 4               Right                 4            5
# ...               ...               ...          ...
# 18534           Right                 3            2
# 18535           Right                 3            2
# 18536           Right                 3            2
# 18537           Right                 3            2
# 18538            Left                 3            2
#
#        International Reputation National Team Name  \
# 0                             5          Argentina
# 1                             4             France
# 2                             5             Poland
# 3                             4            Belgium
# 4                             4             France
# ...                         ...                ...
# 18534                         1                  -
# 18535                         1                  -
# 18536                         1                  -
# 18537                         1                  -
# 18538                         1                  -
#
#                   National Team Image Link  National Team Position  \
# 0      https://cdn.sofifa.net/flags/ar.png                      RW
# 1      https://cdn.sofifa.net/flags/fr.png                      ST
# 2      https://cdn.sofifa.net/flags/pl.png                      ST
# 3      https://cdn.sofifa.net/flags/be.png                      RF
# 4      https://cdn.sofifa.net/flags/fr.png                      ST
# ...                                    ...                     ...
# 18534                                    -                       -
# 18535                                    -                       -
# 18536                                    -                       -
# 18537                                    -                       -
# 18538                                    -                       -
#
#       National Team Jersey Number Attacking Work Rate Defensive Work Rate
# 0                              10                 Low                 Low
# 1                              19              Medium              Medium
# 2                               9                High              Medium
# 3                               7                High                High
# 4                              10                High                 Low
# ...                           ...                 ...                 ...
# 18534                           -              Medium              Medium
# 18535                           -              Medium              Medium
# 18536                           -                High              Medium
# 18537                           -              Medium              Medium
# 18538                           -              Medium              Medium
#
# [18539 rows x 32 columns]

# %% [markdown]
# <font size = "5">
#
# (a) Create a function and apply it to a column <br>
#
# <font size = "3">
#
# Step 1:
# - Define a function with a parameter "overall"
# - If "overall < 85", status = "Regular Player"
# - If "age_player >= 85", status = "Top Player"
# - The function returns "status"
#
# Step 2:
# - Extract the column "Overall" in the dataset <br>
# (be carefeful to write the "O" capitalized)
# - Create a new variable called "top_players" <br>
# to assign each player to the correct status
#
# HINT: Use the ".apply()" function

# %%
# Write your own code
def player_status(overall):
    if (overall >= 85):
        return 'Top Player'
    else:
        return 'Regular Player'
    
fifa23_subOverall = fifa23['Overall']

fifa23['top_player'] = fifa23_subOverall.apply(player_status)
#fifa23['top_player'] = list(map(player_status, fifa23_subOverall))

display(fifa23)
# Out:
#              Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0            L. Messi        Lionel Messi       91         91        54000000
# 1          K. Benzema       Karim Benzema       91         91        64000000
# 2      R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3        K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4           K. Mbappé       Kylian Mbappé       91         95       190500000
# ...               ...                 ...      ...        ...             ...
# 18534      D. Collins      Darren Collins       47         56          110000
# 18535    Yang Dejiang        Dejiang Yang       47         57           90000
# 18536       L. Mullan         Liam Mullan       47         67          130000
# 18537    D. McCallion    Daithí McCallion       47         61          100000
# 18538        N. Rabha         Nabin Rabha       47         50           60000
#
#       Positions Played Best Position          Nationality  \
# 0                   RW           CAM            Argentina
# 1                CF,ST            CF               France
# 2                   ST            ST               Poland
# 3               CM,CAM            CM              Belgium
# 4                ST,LW            ST               France
# ...                ...           ...                  ...
# 18534            ST,RM           CAM  Republic of Ireland
# 18535              CDM           CDM             China PR
# 18536               CM            RM     Northern Ireland
# 18537               CB            CB  Republic of Ireland
# 18538               LB            LB                India
#
#                                              Image Link  Age  ...  \
# 0      https://cdn.sofifa.net/players/158/023/23_60.png   35  ...
# 1      https://cdn.sofifa.net/players/165/153/23_60.png   34  ...
# 2      https://cdn.sofifa.net/players/188/545/23_60.png   33  ...
# 3      https://cdn.sofifa.net/players/192/985/23_60.png   31  ...
# 4      https://cdn.sofifa.net/players/231/747/23_60.png   23  ...
# ...                                                 ...  ...  ...
# 18534  https://cdn.sofifa.net/players/243/725/23_60.png   21  ...
# 18535  https://cdn.sofifa.net/players/261/933/23_60.png   17  ...
# 18536  https://cdn.sofifa.net/players/267/823/23_60.png   18  ...
# 18537  https://cdn.sofifa.net/players/267/824/23_60.png   17  ...
# 18538  https://cdn.sofifa.net/players/261/424/23_60.png   25  ...
#
#        Weak Foot Rating  Skill Moves  International Reputation  \
# 0                     4            4                         5
# 1                     4            4                         4
# 2                     4            4                         5
# 3                     5            4                         4
# 4                     4            5                         4
# ...                 ...          ...                       ...
# 18534                 3            2                         1
# 18535                 3            2                         1
# 18536                 3            2                         1
# 18537                 3            2                         1
# 18538                 3            2                         1
#
#        National Team Name             National Team Image Link  \
# 0               Argentina  https://cdn.sofifa.net/flags/ar.png
# 1                  France  https://cdn.sofifa.net/flags/fr.png
# 2                  Poland  https://cdn.sofifa.net/flags/pl.png
# 3                 Belgium  https://cdn.sofifa.net/flags/be.png
# 4                  France  https://cdn.sofifa.net/flags/fr.png
# ...                   ...                                  ...
# 18534                   -                                    -
# 18535                   -                                    -
# 18536                   -                                    -
# 18537                   -                                    -
# 18538                   -                                    -
#
#        National Team Position  National Team Jersey Number  \
# 0                          RW                           10
# 1                          ST                           19
# 2                          ST                            9
# 3                          RF                            7
# 4                          ST                           10
# ...                       ...                          ...
# 18534                       -                            -
# 18535                       -                            -
# 18536                       -                            -
# 18537                       -                            -
# 18538                       -                            -
#
#       Attacking Work Rate Defensive Work Rate      top_player
# 0                     Low                 Low      Top Player
# 1                  Medium              Medium      Top Player
# 2                    High              Medium      Top Player
# 3                    High                High      Top Player
# 4                    High                 Low      Top Player
# ...                   ...                 ...             ...
# 18534              Medium              Medium  Regular Player
# 18535              Medium              Medium  Regular Player
# 18536                High              Medium  Regular Player
# 18537              Medium              Medium  Regular Player
# 18538              Medium              Medium  Regular Player
#
# [18539 rows x 33 columns]

# %% [markdown]
# <font size = "5">
#
# (b) Use queries + global variables
#
# <font size = "3">
#
# - Compute the mean of the column "Wage(in Euro)" <br>
# and store it as a variable
# - Subset the players whose value is above the mean value <br>
#   using ".query()"
#
#
# HINT: Remember that there is a special syntax for <br>
# when the column names have spaces (see Lecture 9) <br>
# Reference the column as ``` `Wage(in Euro)`    ``` inside .query()

# %%
# Write your own code
mean_wage = np.mean(fifa23['Wage(in Euro)'])
print(mean_wage)

data_highWage = fifa23.query(" `Wage(in Euro)` > @mean_wage")

display(data_highWage)
# Out:
# 8824.537461567506
#                  Known As                 Full Name  Overall  Potential  \
# 0                L. Messi              Lionel Messi       91         91
# 1              K. Benzema             Karim Benzema       91         91
# 2          R. Lewandowski        Robert Lewandowski       91         91
# 3            K. De Bruyne           Kevin De Bruyne       91         91
# 4               K. Mbappé             Kylian Mbappé       91         95
# ...                   ...                       ...      ...        ...
# 14279            A. Lewis                Adam Lewis       61         65
# 15117           B. Knight                Ben Knight       60         74
# 15441  T. Suengchitthawon  Thanawat Suengchitthawon       60         70
# 15957          P. Glatzel              Paul Glatzel       59         65
# 16157      C. Chukwuemeka         Caleb Chukwuemeka       58         71
#
#        Value(in Euro) Positions Played Best Position Nationality  \
# 0            54000000               RW           CAM   Argentina
# 1            64000000            CF,ST            CF      France
# 2            84000000               ST            ST      Poland
# 3           107500000           CM,CAM            CM     Belgium
# 4           190500000            ST,LW            ST      France
# ...               ...              ...           ...         ...
# 14279          450000           LWB,LB           LWB     England
# 15117          600000               RW           CAM     England
# 15441          550000              CAM            RM    Thailand
# 15957          375000               ST            ST     Germany
# 16157          500000         RW,RM,LW            ST     England
#
#                                              Image Link  Age  ...  \
# 0      https://cdn.sofifa.net/players/158/023/23_60.png   35  ...
# 1      https://cdn.sofifa.net/players/165/153/23_60.png   34  ...
# 2      https://cdn.sofifa.net/players/188/545/23_60.png   33  ...
# 3      https://cdn.sofifa.net/players/192/985/23_60.png   31  ...
# 4      https://cdn.sofifa.net/players/231/747/23_60.png   23  ...
# ...                                                 ...  ...  ...
# 14279  https://cdn.sofifa.net/players/243/056/23_60.png   22  ...
# 15117  https://cdn.sofifa.net/players/263/955/23_60.png   20  ...
# 15441  https://cdn.sofifa.net/players/259/324/23_60.png   22  ...
# 15957  https://cdn.sofifa.net/players/247/507/23_60.png   21  ...
# 16157  https://cdn.sofifa.net/players/258/748/23_60.png   20  ...
#
#        Weak Foot Rating  Skill Moves  International Reputation  \
# 0                     4            4                         5
# 1                     4            4                         4
# 2                     4            4                         5
# 3                     5            4                         4
# 4                     4            5                         4
# ...                 ...          ...                       ...
# 14279                 2            2                         1
# 15117                 3            3                         1
# 15441                 3            2                         1
# 15957                 3            3                         1
# 16157                 4            3                         1
#
#        National Team Name                 National Team Image Link  \
# 0               Argentina      https://cdn.sofifa.net/flags/ar.png
# 1                  France      https://cdn.sofifa.net/flags/fr.png
# 2                  Poland      https://cdn.sofifa.net/flags/pl.png
# 3                 Belgium      https://cdn.sofifa.net/flags/be.png
# 4                  France      https://cdn.sofifa.net/flags/fr.png
# ...                   ...                                      ...
# 14279                   -  https://cdn.sofifa.net/flags/gb-eng.png
# 15117                   -  https://cdn.sofifa.net/flags/gb-eng.png
# 15441                   -                                        -
# 15957                   -      https://cdn.sofifa.net/flags/de.png
# 16157                   -  https://cdn.sofifa.net/flags/gb-eng.png
#
#        National Team Position  National Team Jersey Number  \
# 0                          RW                           10
# 1                          ST                           19
# 2                          ST                            9
# 3                          RF                            7
# 4                          ST                           10
# ...                       ...                          ...
# 14279                       -                            -
# 15117                       -                            -
# 15441                       -                            -
# 15957                       -                            -
# 16157                       -                            -
#
#       Attacking Work Rate Defensive Work Rate      top_player
# 0                     Low                 Low      Top Player
# 1                  Medium              Medium      Top Player
# 2                    High              Medium      Top Player
# 3                    High                High      Top Player
# 4                    High                 Low      Top Player
# ...                   ...                 ...             ...
# 14279              Medium              Medium  Regular Player
# 15117              Medium              Medium  Regular Player
# 15441              Medium              Medium  Regular Player
# 15957              Medium                 Low  Regular Player
# 16157              Medium                 Low  Regular Player
#
# [4300 rows x 33 columns]

# %% [markdown]
# <font size = "5">
#
# (c) Use sorting + ".iloc[]"
#
# <font size = "3">
#
# - Use ".sort_values()" to order the "Age" column <br>
# from youngest to oldest
# - Get a subset with the 5 youngest players
# - Print their age

# %%
# Write your own code
fifa23 = fifa23.sort_values(by = "Age", ascending = True)

subset_youngest5 = fifa23.iloc[0:5, :]

print(list(subset_youngest5['Age']))
# Out:
# [16, 16, 16, 16, 16]

# %% [markdown]
# <font size = "5">
#
# (d) Create a function with four inputs $f(y,x,b0,b1)$
#
# <font size = "3">
#
# $\qquad e2 = (y - b_0 - b_1 * x)^2$
#
# - The function should return the mean of e2
# - This is the mean-square error (mse)
# - Call the function "fn_mse"
# - Let $y$ be the column "Potential"
# - Let $x$ be the column "Age"
# - Does <br>
# $\qquad (b_0 = 80, b_1 = 0.4)$ or <br>
# $\qquad (b_0 = 80, b_1 =-0.3)$ or <br>
# $\qquad (b_0 = 80, b_1 = -0.5)$ <br>
# produce the lowest value of mse?
# - Print your results

# %%
# Write your own code
def fn_mse(y, x, b0, b1):
     e2 = (y - b0 - b1*x)**2
     return np.mean(e2)

f1 = fn_mse(fifa23['Potential'], fifa23['Age'], 80, 0.4)
f2 = fn_mse(fifa23['Potential'], fifa23['Age'], 80, -0.3)
f3 = fn_mse(fifa23['Potential'], fifa23['Age'], 80, -0.5)

print("b0 = 80, b1 = 0.4 produces a mse value of " + str(f1))
print("b0 = 80, b1 = -0.3 produces a mse value of " + str(f2))
print("b0 = 80, b1 = -0.5 produces a mse value of " + str(f3))

print("b0 = 80 and b1 = -0.3 produces the lowest value of mse")
# Out:
# b0 = 80, b1 = 0.4 produces a mse value of 412.1016840174767
# b0 = 80, b1 = -0.3 produces a mse value of 37.72189870003776
# b0 = 80, b1 = -0.5 produces a mse value of 49.43713253142025
# b0 = 80 and b1 = -0.3 produces the lowest value of mse

# %% [markdown]
# <font size = "5">
#
# (e) Split a dataset into subsets
#
# <font size = "3">
#
# - Create ``` list_status = [0,1]```
# - Create ``` list_prob = [0.5, 0.5]```
# - Create a new variable $n$ with the number of rows of the dataset
# - Define a random seed that equals 42
#
# - Use
# ```python
#     np.random.choice(list_status,
#                      size = n,
#                      p = list_prob)
# ```
# $\qquad$ to create a new column called "status" <br>
# $\qquad$ which randomly assigns each row to "0" or "1" <br>
# $\qquad$ with equal probability
# - Use .query() to subset all observations with status == 0.<br>
# store it in a new dataset called "data0"
# - Use .query() to subset all observations with status == 1.<br>
# store it in a new dataset called "data1"

# %%
# Write your own code
list_status = [0,1]
list_prob = [0.5, 0.5]
n = len(fifa23)

np.random.seed(42)

fifa23['status'] = np.random.choice(list_status, size = n, p = list_prob)

data0 = fifa23.query('status == 0')
display(data0)
data1 = fifa23.query('status == 1')
display(data1)
# Out:
#             Known As             Full Name  Overall  Potential  \
# 17956     A. Dithmer       Andreas Dithmer       53         76
# 17591  A. Madaliński       Alan Madaliński       54         68
# 17562     J. Lewicki         Jakub Lewicki       54         73
# 18459       E. Topcu            Emre Topcu       49         59
# 17368      A. Mazilu         Adrian Mazilu       55         75
# ...              ...                   ...      ...        ...
# 13086     A. Narciso       Antonio Narciso       62         62
# 9824       A. Pomini        Alberto Pomini       65         65
# 3635         Bracali  Rafael Wihby Bracali       71         71
# 3276      S. Torrico     Sebastián Torrico       72         72
# 592        G. Buffon      Gianluigi Buffon       79         79
#
#        Value(in Euro) Positions Played Best Position          Nationality  \
# 17956          275000               GK            GK              Denmark
# 17591          210000               GK            GK               Poland
# 17562          250000           LWB,LM           LWB               Poland
# 18459          100000               CM           CAM  Republic of Ireland
# 17368          350000            ST,RW            ST              Romania
# ...               ...              ...           ...                  ...
# 13086           45000               GK            GK                Italy
# 9824            80000               GK            GK                Italy
# 3635           210000               GK            GK               Brazil
# 3276           250000               GK            GK            Argentina
# 592           1900000               GK            GK                Italy
#
#                                              Image Link  Age  ...  \
# 17956  https://cdn.sofifa.net/players/269/573/23_60.png   16  ...
# 17591  https://cdn.sofifa.net/players/270/590/23_60.png   16  ...
# 17562  https://cdn.sofifa.net/players/270/715/23_60.png   16  ...
# 18459  https://cdn.sofifa.net/players/271/072/23_60.png   16  ...
# 17368  https://cdn.sofifa.net/players/270/867/23_60.png   16  ...
# ...                                                 ...  ...  ...
# 13086  https://cdn.sofifa.net/players/178/434/23_60.png   41  ...
# 9824   https://cdn.sofifa.net/players/188/017/23_60.png   41  ...
# 3635   https://cdn.sofifa.net/players/178/571/23_60.png   41  ...
# 3276   https://cdn.sofifa.net/players/216/692/23_60.png   42  ...
# 592    https://cdn.sofifa.net/players/001/179/23_60.png   44  ...
#
#        Skill Moves  International Reputation  National Team Name  \
# 17956            1                         1                   -
# 17591            1                         1                   -
# 17562            2                         1                   -
# 18459            2                         1                   -
# 17368            2                         1                   -
# ...            ...                       ...                 ...
# 13086            1                         1                   -
# 9824             1                         1                   -
# 3635             1                         1                   -
# 3276             1                         1                   -
# 592              1                         4                   -
#
#                   National Team Image Link National Team Position  \
# 17956  https://cdn.sofifa.net/flags/dk.png                      -
# 17591  https://cdn.sofifa.net/flags/pl.png                      -
# 17562  https://cdn.sofifa.net/flags/pl.png                      -
# 18459                                    -                      -
# 17368  https://cdn.sofifa.net/flags/ro.png                      -
# ...                                    ...                    ...
# 13086  https://cdn.sofifa.net/flags/it.png                      -
# 9824   https://cdn.sofifa.net/flags/it.png                      -
# 3635   https://cdn.sofifa.net/flags/br.png                      -
# 3276   https://cdn.sofifa.net/flags/ar.png                      -
# 592    https://cdn.sofifa.net/flags/it.png                      -
#
#        National Team Jersey Number  Attacking Work Rate Defensive Work Rate  \
# 17956                            -               Medium              Medium
# 17591                            -               Medium              Medium
# 17562                            -               Medium              Medium
# 18459                            -               Medium              Medium
# 17368                            -                 High                 Low
# ...                            ...                  ...                 ...
# 13086                            -               Medium              Medium
# 9824                             -               Medium              Medium
# 3635                             -               Medium              Medium
# 3276                             -               Medium              Medium
# 592                              -               Medium              Medium
#
#            top_player status
# 17956  Regular Player      0
# 17591  Regular Player      0
# 17562  Regular Player      0
# 18459  Regular Player      0
# 17368  Regular Player      0
# ...               ...    ...
# 13086  Regular Player      0
# 9824   Regular Player      0
# 3635   Regular Player      0
# 3276   Regular Player      0
# 592    Regular Player      0
#
# [9304 rows x 34 columns]
#            Known As            Full Name  Overall  Potential  Value(in Euro)  \
# 18014     J. Ardila          José Ardila       53         73          250000
# 16084      S. Ngoma          Serge Ngoma       58         82          650000
# 11481     O. Vargas          Obed Vargas       64         81         1500000
# 17476      D. Benga          Denis Benga       55         73          300000
# 18447   Du Yuezheng          Yuezheng Du       49         67          120000
# ...             ...                  ...      ...        ...             ...
# 10851     M. Galezo        Moisés Galezo       64         64               0
# 1920        J. Sand            José Sand       74         74               0
# 2423   Rubén Castro  Rubén Castro Martín       73         73               0
# 4499      G. Pegolo      Gianluca Pegolo       70         70          180000
# 13548      S. Lukić         Stojan Lukić       62         62           45000
#
#       Positions Played Best Position             Nationality  \
# 18014               CM           CAM               Venezuela
# 16084               RW            RM           United States
# 11481        CM,CDM,RM           CAM           United States
# 17476               LB            LB                 Romania
# 18447               ST            ST                China PR
# ...                ...           ...                     ...
# 10851               CB            CB               Venezuela
# 1920                ST            ST               Argentina
# 2423                ST            ST                   Spain
# 4499                GK            GK                   Italy
# 13548               GK            GK  Bosnia and Herzegovina
#
#                                              Image Link  Age  ...  \
# 18014  https://cdn.sofifa.net/players/268/892/23_60.png   16  ...
# 16084  https://cdn.sofifa.net/players/267/796/23_60.png   16  ...
# 11481  https://cdn.sofifa.net/players/263/701/23_60.png   16  ...
# 17476  https://cdn.sofifa.net/players/271/181/23_60.png   16  ...
# 18447  https://cdn.sofifa.net/players/269/128/23_60.png   16  ...
# ...                                                 ...  ...  ...
# 10851  https://cdn.sofifa.net/players/265/721/23_60.png   41  ...
# 1920   https://cdn.sofifa.net/players/152/912/23_60.png   41  ...
# 2423   https://cdn.sofifa.net/players/115/909/23_60.png   41  ...
# 4499   https://cdn.sofifa.net/players/106/795/23_60.png   41  ...
# 13548  https://cdn.sofifa.net/players/213/483/23_60.png   42  ...
#
#        Skill Moves  International Reputation  National Team Name  \
# 18014            2                         1                   -
# 16084            2                         1                   -
# 11481            3                         1                   -
# 17476            2                         1                   -
# 18447            2                         1                   -
# ...            ...                       ...                 ...
# 10851            2                         1                   -
# 1920             3                         1                   -
# 2423             3                         2                   -
# 4499             1                         1                   -
# 13548            1                         1                   -
#
#                   National Team Image Link National Team Position  \
# 18014  https://cdn.sofifa.net/flags/ve.png                      -
# 16084  https://cdn.sofifa.net/flags/us.png                      -
# 11481  https://cdn.sofifa.net/flags/us.png                      -
# 17476  https://cdn.sofifa.net/flags/ro.png                      -
# 18447                                    -                      -
# ...                                    ...                    ...
# 10851  https://cdn.sofifa.net/flags/ve.png                      -
# 1920   https://cdn.sofifa.net/flags/ar.png                      -
# 2423   https://cdn.sofifa.net/flags/es.png                      -
# 4499   https://cdn.sofifa.net/flags/it.png                      -
# 13548                                    -                      -
#
#        National Team Jersey Number  Attacking Work Rate Defensive Work Rate  \
# 18014                            -               Medium              Medium
# 16084                            -                 High              Medium
# 11481                            -                 High              Medium
# 17476                            -                  Low                High
# 18447                            -               Medium              Medium
# ...                            ...                  ...                 ...
# 10851                            -               Medium                High
# 1920                             -                 High                 Low
# 2423                             -               Medium                 Low
# 4499                             -               Medium              Medium
# 13548                            -               Medium              Medium
#
#            top_player status
# 18014  Regular Player      1
# 16084  Regular Player      1
# 11481  Regular Player      1
# 17476  Regular Player      1
# 18447  Regular Player      1
# ...               ...    ...
# 10851  Regular Player      1
# 1920   Regular Player      1
# 2423   Regular Player      1
# 4499   Regular Player      1
# 13548  Regular Player      1
#
# [9235 rows x 34 columns]

# %% [markdown]
# <font size = "5">
#
# (f) Create two overlapping histogram plots
#
# <font size = "3">
#
# - This question requires the two datasets you created in (e)
# - Display the distribution of "Age" for "data0" and "data1"
# - Use the "alpha" option to make the graphs semitransparent
# - You will need to add a legend, label the axes, and the title
#
# Note: The goal of this question is to illustrate that random <br>
# assignment produces very similar distributions between two groups
#
# - Provide a short interpretation of the graph using the information from the Note

# %%
# Write your own code
for status in list_status:
    df = fifa23.query('status == @status')
    plt.hist(x = df['Age'], alpha = 0.5)

plt.xlabel('Age')
plt.ylabel('frequency')
plt.legend(labels = list_status, 
           title = "Status")

plt.show()

print("As shown on the graph, the histogram of the distribution of age for players in status 0 and 1 are very similar.")
print("This is because the random assignment into the status groups had an equal probability.")
# Out:
# As shown on the graph, the histogram of the distribution of age for players in status 0 and 1 are very similar.
# This is because the random assignment into the status groups had an equal probability.
